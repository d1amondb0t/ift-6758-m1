# %%
from advanced_visualization import export_offensive_zone_figures

paths = export_offensive_zone_figures(
    seasons=[20162017, 20172018, 20182019, 20192020, 20202021],
)

# %%
from advanced_visualization import plot_team_excess_shot_map

plot_team_excess_shot_map(20172018, 'Sharks')

# %%
from advanced_visualization import interactive_team_shot_map

interactive_team_shot_map()

# %%
from advanced_visualization import interactive_team_shot_map_plotly_with_widgets

interactive_team_shot_map_plotly_with_widgets()
