# %%
import advanced_visualization

# %%
heatmap = advanced_visualization.heatmap_data("Avalanche",20202021)

# %%
heatmap
# Out:
# coordinates_y_bins  (-42.5, -33.056]  (-33.056, -23.611]  (-23.611, -14.167]  \
# coordinates_x_bins
# (0.0, 11.111]               0.022248            0.008935            0.000770
# (11.111, 22.222]            0.033945           -0.053820           -0.038811
# (22.222, 33.333]           -0.041911           -0.142395            0.009820
# (33.333, 44.444]           -0.040661           -0.027786            0.230489
# (44.444, 55.556]           -0.051417            0.012240           -0.027318
# (55.556, 66.667]            0.084261           -0.002769           -0.307253
# (66.667, 77.778]           -0.040926           -0.062551           -0.273945
# (77.778, 88.889]           -0.066989           -0.031485           -0.095685
# (88.889, 100.0]            -0.002078           -0.023103           -0.023950
#
# coordinates_y_bins  (-14.167, -4.722]  (-4.722, 4.722]  (4.722, 14.167]  \
# coordinates_x_bins
# (0.0, 11.111]               -0.032479        -0.051307        -0.017039
# ...

# %%
from scipy.ndimage import gaussian_filter
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd 

indexes = heatmap.index 
y_cols = heatmap.columns
df_finale = pd.DataFrame(heatmap, index=indexes, columns=y_cols)
plt.imshow(df_finale, cmap="bwr", interpolation='bilinear', vmin=-1, vmax=1)
plt.colorbar() 
plt.show()
