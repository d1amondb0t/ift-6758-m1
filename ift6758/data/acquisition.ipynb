# %%
import acquisition

# %%
for year in range(2016,2024):
    acquisition.download_all(year, output_path="./dataStore")

# %%
import tidying
all_games_events = tidying.load_all_games_events()
df = tidying.events_to_dataframe(all_games_events)
df.head()
# Out:
#       game_id                 game_time  period period_time event_type  \
# 0  2016020001 2016-10-12 23:00:00+00:00       1       01:11       shot
# 1  2016020001 2016-10-12 23:00:00+00:00       1       02:53       shot
# 2  2016020001 2016-10-12 23:00:00+00:00       1       04:01       shot
# 3  2016020001 2016-10-12 23:00:00+00:00       1       04:46       shot
# 4  2016020001 2016-10-12 23:00:00+00:00       1       06:46       shot
#
#    team_id  coordinates_x  coordinates_y          shooter             goalie  \
# 0       10            -77              5     Mitch Marner     Craig Anderson
# 1        9             86             13      Chris Kelly  Frederik Andersen
# 2        9             23            -38        Cody Ceci  Frederik Andersen
# 3        9             33            -15    Erik Karlsson  Frederik Andersen
# 4       10            -34             28  Martin Marincin     Craig Anderson
#
#   shot_type
# 0     wrist
# 1     wrist
# 2     wrist
# 3      slap
# ...
