# %%
import acquisition

# %%
for year in range(2016,2024):
    acquisition.download_all(year, output_path="./dataStore")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 2
#       1 for year in range(2016,2024):
# ----> 2     acquisition.download_all(year, output_path="./dataStore")
#
# File c:\Users\aniss\Documents\Session A25_MIng\IFT6758\ift-6758-m1\ift6758\data\acquisition.py:123, in download_all(start_year, output_path)
#     113 def download_all(start_year, output_path):
#     114     """
#     115     Download both regular-season and playoff games for a  season.
#     116
#    (...)    121     :return: None
#     122     """
# --> 123     download_regular(start_year, output_path)
#     124     download_playoff(start_year, output_path)
#
# File c:\Users\aniss\Documents\Session A25_MIng\IFT6758\ift-6758-m1\ift6758\data\acquisition.py:84, in download_regular(start_year, output_path)
#      82 output_path = os.path.join(output_path, str(start_year), "regular")
#      83 while game_id <= end_id:
# ---> 84     get_game(game_id, output_path)
#      85     game_id += 1
#
# File c:\Users\aniss\Documents\Session A25_MIng\IFT6758\ift-6758-m1\ift6758\data\acquisition.py:55, in get_game(game_id, out_dir)
#      53 url = f"{BASE_URL}/{game_id}/play-by-play"
#      54 try:
# ---> 55     r = requests.get(url)
#      56 except requests.RequestException:
#      57     return "fail"
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\aniss\miniconda3\envs\ift6758-conda-env\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import tidying
all_games_events = tidying.load_all_games_events()
df = tidying.events_to_dataframe(all_games_events)
df.head()
# Out:
# 100%|██████████| 8/8 [04:36<00:00, 34.52s/it]
# 100%|██████████| 8963/8963 [09:55<00:00, 15.04it/s]
#       game_id    season                 game_time  period period_time  \
# 0  2016020001  20162017 2016-10-12 23:00:00+00:00       1       01:11
# 1  2016020001  20162017 2016-10-12 23:00:00+00:00       1       02:53
# 2  2016020001  20162017 2016-10-12 23:00:00+00:00       1       04:01
# 3  2016020001  20162017 2016-10-12 23:00:00+00:00       1       04:46
# 4  2016020001  20162017 2016-10-12 23:00:00+00:00       1       06:46
#
#   event_type  team_id    team_name  coordinates_x  coordinates_y  \
# 0       shot       10  Maple Leafs          -77.0            5.0
# 1       shot        9     Senators           86.0           13.0
# 2       shot        9     Senators           23.0          -38.0
# 3       shot        9     Senators           33.0          -15.0
# 4       shot       10  Maple Leafs          -34.0           28.0
#
#            shooter             goalie shot_type  empty_net       strength  \
# 0     Mitch Marner     Craig Anderson     wrist      False  Even Strength
# 1      Chris Kelly  Frederik Andersen     wrist      False  Even Strength
# 2        Cody Ceci  Frederik Andersen     wrist      False  Even Strength
# 3    Erik Karlsson  Frederik Andersen      slap      False  Even Strength
# 4  Martin Marincin     Craig Anderson     wrist      False  Even Strength
#
#   situation_code
# 0           1551
# 1           1551
# 2           1551
# 3           1551
# 4           1551

# %%
#simple vizualization
import simple_visualization  as sv
sv.plot_shots_simple(df)

# %%
sv.plot_distance_analysis(df)

# %%
sv.plot_distance_by_shot_type(df)
