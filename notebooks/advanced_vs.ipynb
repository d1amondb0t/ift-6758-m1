# %% [markdown]
# Before using this notebook, please ensure you’ve completed both the acquisition and tidying steps. The necessary CSV files and processed data must be generated beforehand for this notebook to run properly.

# %%
import sys, os 
sys.path.append(os.path.abspath('..'))
from ift6758.data import advanced_visualization
paths = advanced_visualization.export_offensive_zone_figures(
    seasons=[20162017, 20172018, 20182019, 20192020, 20202021], out_dir="../ift6758/data/plot_figures/", rink_image_path="../figures/nhl_rink_half.png"
)
