# %%
import sys, os 
sys.path.append(os.path.abspath('..'))
from ift6758.data import load_game
from ift6758.data.tidying import load_all_games_events 
from ift6758.data.tidying  import events_to_dataframe 
import json
import os
from tqdm import tqdm
import pandas as pd
from ift6758.data.acquisition import read_json

# %%
if __name__ == "__main__":

    # Charger tous les événements de tous les matchs
    
    print("Loading all games events...")
    all_games_events = load_all_games_events(base_path='../ift6758/data/dataStore')
    # print(f"Total games loaded: {len(all_games_events)}")

    # Convertir en DataFrame
    print("Converting events to DataFrame...")
    df = events_to_dataframe(all_games_events)
    print(df)
    print(f"Total events extracted: {len(df)}")

    # Optionnel : sauvegarder en CSV pour utilisation future
    output_csv = "all_shots_goals.csv"
    df.to_csv('../ift6758/data/'+output_csv, index=False)
    print(f"DataFrame saved to {output_csv}")
# Out:
# Loading all games events...
# 100%|██████████| 8/8 [06:45<00:00, 50.65s/it]
# Converting events to DataFrame...
# 100%|██████████| 10345/10345 [00:40<00:00, 254.74it/s]
#            game_id    season                 game_time  period period_time  \
# 0       2016020001  20162017 2016-10-12 23:00:00+00:00       1       01:11
# 1       2016020001  20162017 2016-10-12 23:00:00+00:00       1       02:53
# 2       2016020001  20162017 2016-10-12 23:00:00+00:00       1       04:01
# 3       2016020001  20162017 2016-10-12 23:00:00+00:00       1       04:46
# 4       2016020001  20162017 2016-10-12 23:00:00+00:00       1       06:46
# ...            ...       ...                       ...     ...         ...
# 647308  2023030417  20232024 2024-06-25 00:00:00+00:00       3       12:57
# 647309  2023030417  20232024 2024-06-25 00:00:00+00:00       3       14:25
# 647310  2023030417  20232024 2024-06-25 00:00:00+00:00       3       15:23
# 647311  2023030417  20232024 2024-06-25 00:00:00+00:00       3       15:48
# 647312  2023030417  20232024 2024-06-25 00:00:00+00:00       3       17:42
#
#        event_type  team_id    team_name  coordinates_x  coordinates_y  \
# 0            shot       10  Maple Leafs          -77.0            5.0
# 1            shot        9     Senators           86.0           13.0
# 2            shot        9     Senators           23.0          -38.0
# 3            shot        9     Senators           33.0          -15.0
# 4            shot       10  Maple Leafs          -34.0           28.0
# ...           ...      ...          ...            ...            ...
# 647308       shot       22       Oilers           85.0            1.0
# 647309       shot       13     Panthers          -52.0          -27.0
# 647310       shot       13     Panthers          -59.0          -29.0
# 647311       shot       22       Oilers           57.0          -26.0
# 647312       shot       22       Oilers           84.0            3.0
#
#                    shooter             goalie shot_type  empty_net  \
# 0             Mitch Marner     Craig Anderson     wrist      False
# 1              Chris Kelly  Frederik Andersen     wrist      False
# 2                Cody Ceci  Frederik Andersen     wrist      False
# 3            Erik Karlsson  Frederik Andersen      slap      False
# 4          Martin Marincin     Craig Anderson     wrist      False
# ...                    ...                ...       ...        ...
# 647308          Zach Hyman   Sergei Bobrovsky      poke      False
# 647309  Vladimir Tarasenko     Stuart Skinner     wrist      False
# 647310   Aleksander Barkov     Stuart Skinner      snap      False
# 647311       Darnell Nurse   Sergei Bobrovsky     wrist      False
# 647312      Mattias Ekholm   Sergei Bobrovsky     wrist      False
#
#              strength situation_code
# 0       Even Strength           1551
# 1       Even Strength           1551
# 2       Even Strength           1551
# 3       Even Strength           1551
# 4       Even Strength           1551
# ...               ...            ...
# 647308  Even Strength           1551
# 647309  Even Strength           1551
# 647310  Even Strength           1551
# 647311  Even Strength           1551
# 647312  Even Strength           1551
#
# [647313 rows x 16 columns]
# Total events extracted: 647313
# DataFrame saved to all_shots_goals.csv

# %%
df.columns
# Out:
# Index(['game_id', 'game_time', 'period', 'period_time', 'event_type',
#        'team_id', 'team_name', 'coordinates_x', 'coordinates_y', 'shooter',
#        'goalie', 'shot_type', 'empty_net', 'strength', 'situation_code'],
#       dtype='object')

# %%
df.head(100)
# Out:
#        game_id                 game_time  period period_time event_type  \
# 0   2016020001 2016-10-12 23:00:00+00:00       1       01:11       shot
# 1   2016020001 2016-10-12 23:00:00+00:00       1       02:53       shot
# 2   2016020001 2016-10-12 23:00:00+00:00       1       04:01       shot
# 3   2016020001 2016-10-12 23:00:00+00:00       1       04:46       shot
# 4   2016020001 2016-10-12 23:00:00+00:00       1       06:46       shot
# ..         ...                       ...     ...         ...        ...
# 95  2016020002 2016-10-13 00:00:00+00:00       2       13:57       goal
# 96  2016020002 2016-10-13 00:00:00+00:00       2       18:31       shot
# 97  2016020002 2016-10-13 00:00:00+00:00       2       19:04       shot
# 98  2016020002 2016-10-13 00:00:00+00:00       2       19:20       shot
# 99  2016020002 2016-10-13 00:00:00+00:00       2       19:28       goal
#
#     team_id    team_name  coordinates_x  coordinates_y             shooter  \
# 0        10  Maple Leafs          -77.0            5.0        Mitch Marner
# 1         9     Senators           86.0           13.0         Chris Kelly
# 2         9     Senators           23.0          -38.0           Cody Ceci
# 3         9     Senators           33.0          -15.0       Erik Karlsson
# 4        10  Maple Leafs          -34.0           28.0     Martin Marincin
# ..      ...          ...            ...            ...                 ...
# 95       16   Blackhawks           80.0            6.0        Ryan Hartman
# 96       19        Blues          -67.0           26.0  Vladimir Tarasenko
# 97       19        Blues          -46.0          -29.0   Kevin Shattenkirk
# 98       19        Blues          -43.0           -4.0  Vladimir Tarasenko
# 99       19        Blues          -50.0           18.0  Vladimir Tarasenko
#
#                goalie shot_type  empty_net       strength situation_code
# 0      Craig Anderson     wrist      False  Even Strength           1551
# 1   Frederik Andersen     wrist      False  Even Strength           1551
# 2   Frederik Andersen     wrist      False  Even Strength           1551
# 3   Frederik Andersen      slap      False  Even Strength           1551
# 4      Craig Anderson     wrist      False  Even Strength           1551
# ..                ...       ...        ...            ...            ...
# 95         Jake Allen  backhand      False  Even Strength           1551
# 96     Corey Crawford      slap      False     Power Play           1541
# 97     Corey Crawford      slap      False     Power Play           1531
# 98     Corey Crawford     wrist      False     Power Play           1531
# 99     Corey Crawford     wrist      False     Power Play           1531
#
# [100 rows x 15 columns]

# %%
#Some Sanity Checks using the reports from Leafs vs Senators and comparing what we have in the df: https://www.nhl.com/scores/htmlreports/20162017/PL020001.HTM 

pp_plays = df[df['strength'].str.contains("Power Play", na=False)]
print(pp_plays.head(1))

#Craig Andersion 87	1	PP	15:22 4:38	SHOT	TOR ONGOAL - #29 NYLANDER, Wrist, Off. Zone, 45 ft.
# Out:
#        game_id                 game_time  period period_time event_type  \
# 16  2016020001 2016-10-12 23:00:00+00:00       1       15:22       shot
#
#     team_id    team_name  coordinates_x  coordinates_y           shooter  \
# 16       10  Maple Leafs          -60.0           34.0  William Nylander
#
#             goalie shot_type  empty_net    strength situation_code
# 16  Craig Anderson     wrist      False  Power Play           1541

# %%
pp_plays = df[df['strength'].str.contains("Even Strength", na=False)]
print(pp_plays.head(1))

#8	1	EV	1:11 18:49	SHOT	TOR ONGOAL - #16 MARNER, Wrist, Off. Zone, 13 ft.
# Out:
#       game_id                 game_time  period period_time event_type  \
# 0  2016020001 2016-10-12 23:00:00+00:00       1       01:11       shot
#
#    team_id    team_name  coordinates_x  coordinates_y       shooter  \
# 0       10  Maple Leafs          -77.0            5.0  Mitch Marner
#
#            goalie shot_type  empty_net       strength situation_code
# 0  Craig Anderson     wrist      False  Even Strength           1551

# %%
pp_plays = df[df['strength'].str.contains("Short-Handed Goal", na=False)]
print(pp_plays.head(1))

#187	2	SH	11:08 8:52	SHOT	OTT ONGOAL - #7 TURRIS, Wrist, Off. Zone, 26 ft.
# Out:
#        game_id                 game_time  period period_time event_type  \
# 35  2016020001 2016-10-12 23:00:00+00:00       2       11:08       shot
#
#     team_id team_name  coordinates_x  coordinates_y      shooter  \
# 35        9  Senators          -64.0            3.0  Kyle Turris
#
#                goalie shot_type  empty_net           strength situation_code
# 35  Frederik Andersen     wrist      False  Short-Handed Goal           1541

# %%
#
