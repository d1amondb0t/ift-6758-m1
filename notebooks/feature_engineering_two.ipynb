# %%
import sys, os 
sys.path.append(os.path.abspath('..'))
import numpy as np
import os
import pandas as pd
from ift6758.data.feature_engineering_pt2 import feature_engineering_two

# %%
df = feature_engineering_two( years = range(2016, 2020))

# %%
df.columns
# Out:
# Index(['game_id', 'season', 'game_time', 'period', 'period_time', 'event_type',
#        'team_id', 'team_name', 'coordinates_x', 'coordinates_y', 'shooter',
#        'goalie', 'shot_type', 'empty_net', 'strength', 'situation_code',
#        'previous_event_name', 'previous_event_x', 'previous_event_y',
#        'previous_event_timeperiod', 'isHomeTeam', 'friendly_skaters',
#        'opponent_skaters', 'zone_code', 'current_event_timeseconds',
#        'previous_event_timeseconds', 'time_since_last_event', 'rebound',
#        'distance_from_last_event', 'angle_shot_prev', 'angle_shot', 'speed',
#        'angle_change', 'distance_shot', 'is_goal'],
#       dtype='object')

# %%
filtered = df[[  'distance_shot', 'game_id', 'period', 'previous_event_name','previous_event_x', 'previous_event_y',  'event_type', 'coordinates_x', 'coordinates_y','shot_type', 'empty_net',  'rebound',  'speed','angle_change', 'distance_from_last_event', 'strength', 'friendly_skaters', 'opponent_skaters']]

# %%
filtered[filtered['rebound'] == True]
# Out:
#         distance_shot     game_id  period previous_event_name  \
# 2           76.157731  2016020001       1         missed-shot
# 3           57.974132  2016020001       1         missed-shot
# 6           19.026298  2016020001       1         missed-shot
# 10          60.415230  2016020001       1        shot-on-goal
# 11           7.615773  2016020001       1        shot-on-goal
# ...               ...         ...     ...                 ...
# 253457      10.049876  2018030417       3        shot-on-goal
# 253462      21.023796  2018030417       3        shot-on-goal
# 253464      14.422205  2018030417       3        shot-on-goal
# 253472      24.331050  2018030417       3        shot-on-goal
# 253474      51.000000  2018030417       3         missed-shot
#
#         previous_event_x  previous_event_y    event_type  coordinates_x  \
# 2                  -72.0               0.0  shot-on-goal           23.0
# 3                   77.0              -2.0  shot-on-goal           33.0
# 6                  -85.0              -8.0          goal          -70.0
# 10                  34.0              20.0  shot-on-goal           34.0
# 11                  34.0             -25.0          goal           82.0
# ...                  ...               ...           ...            ...
# 253457             -55.0              -2.0  shot-on-goal          -79.0
# 253462             -32.0              18.0  shot-on-goal           80.0
# 253464              42.0             -27.0  shot-on-goal           77.0
# 253472             -69.0               7.0  shot-on-goal          -65.0
# 253474              57.0             -13.0          goal           44.0
#
#         coordinates_y shot_type  empty_net  rebound      speed  angle_change  \
# 2               -38.0     wrist      False     True   5.684341     29.931512
# 3               -15.0      slap      False     True   2.414752      5.532757
# 6                 1.0     wrist      False     True   5.830952      2.992781
# 10              -25.0      slap      False     True   5.000000     44.427061
# 11                3.0  backhand      False     True  55.569776     47.642545
# ...               ...       ...        ...      ...        ...           ...
# 253457            1.0     wrist      False     True   6.046693      1.136766
# 253462           19.0     wrist      False     True   3.500140     56.192536
# 253464            8.0     wrist      False     True  16.499158     63.566060
# 253472           -4.0      snap      False     True   2.926175      4.024629
# 253474           24.0     wrist      False     True   0.871497     50.181935
#
#         distance_from_last_event       strength  friendly_skaters  \
# 2                     102.318131  Even Strength                 5
# 3                      45.880279  Even Strength                 5
# 6                      17.492856  Even Strength                 5
# 10                     45.000000  Even Strength                 5
# 11                     55.569776  Even Strength                 5
# ...                          ...            ...               ...
# 253457                 24.186773  Even Strength                 5
# 253462                112.004464  Even Strength                 5
# 253464                 49.497475  Even Strength                 5
# 253472                 11.704700  Even Strength                 5
# 253474                 39.217343  Even Strength                 6
#
#         opponent_skaters
# 2                      5
# 3                      5
# 6                      5
# 10                     5
# 11                     5
# ...                  ...
# 253457                 5
# 253462                 5
# 253464                 5
# 253472                 5
# 253474                 5
#
# [69111 rows x 18 columns]

# %%
filtered[filtered['strength'] != "Even Strength"]
# Out:
#         distance_shot     game_id  period previous_event_name  \
# 16          44.687806  2016020001       1             faceoff
# 17          16.401219  2016020001       1        blocked-shot
# 19          27.658633  2016020001       1             faceoff
# 20          58.309519  2016020001       1             faceoff
# 21          14.560220  2016020001       1        blocked-shot
# ...               ...         ...     ...                 ...
# 253394      24.020824  2018030416       2        blocked-shot
# 253421      21.213203  2018030416       3             faceoff
# 253426      34.525353  2018030417       1        blocked-shot
# 253427      22.203603  2018030417       1                 hit
# 253428      11.045361  2018030417       1                 hit
#
#         previous_event_x  previous_event_y    event_type  coordinates_x  \
# 16                 -69.0              22.0  shot-on-goal          -60.0
# 17                  59.0               1.0  shot-on-goal          -79.0
# 19                  69.0              21.0  shot-on-goal           71.0
# 20                  20.0              22.0  shot-on-goal           35.0
# 21                  55.0             -13.0  shot-on-goal           85.0
# ...                  ...               ...           ...            ...
# 253394             -66.0             -12.0  shot-on-goal          -65.0
# 253421             -69.0              22.0  shot-on-goal          -74.0
# 253426              83.0             -17.0  shot-on-goal           55.0
# 253427              96.0             -11.0  shot-on-goal           67.0
# 253428              89.0              33.0  shot-on-goal           78.0
#
#         coordinates_y shot_type  empty_net  rebound      speed  angle_change  \
# 16               34.0     wrist      False    False   0.652174           0.0
# 17              -13.0     wrist      False    False   4.474462           0.0
# 19              -21.0      snap      False    False   4.671955           0.0
# 20               22.0      slap      False    False   0.535714           0.0
# 21              -14.0     wrist      False    False  15.008331           0.0
# ...               ...       ...        ...      ...        ...           ...
# 253394            1.0    tip-in      False    False   0.343116           0.0
# 253421           15.0     wrist      False    False   1.720465           0.0
# 253426            6.0     wrist      False    False   0.770965           0.0
# 253427            3.0     wrist      False    False   2.146832           0.0
# 253428            1.0  backhand      False    False   3.383785           0.0
#
#         distance_from_last_event      strength  friendly_skaters  \
# 16                     15.000000    Power Play                 5
# 17                    138.708327    Power Play                 5
# 19                     42.047592    Power Play                 5
# 20                     15.000000    Power Play                 5
# 21                     30.016662    Power Play                 5
# ...                          ...           ...               ...
# 253394                 13.038405    Power Play                 5
# 253421                  8.602325  Short-Handed                 3
# 253426                 36.235342    Power Play                 5
# 253427                 32.202484    Power Play                 5
# 253428                 33.837849    Power Play                 5
#
#         opponent_skaters
# 16                     4
# 17                     4
# 19                     4
# 20                     4
# 21                     4
# ...                  ...
# 253394                 4
# 253421                 4
# 253426                 4
# 253427                 4
# 253428                 4
#
# [42792 rows x 18 columns]
