# %%
import sys, os 
sys.path.append(os.path.abspath('..'))
import numpy as np
import os
import pandas as pd
from ift6758.data.feature_enginerring_pt2 import feature_engineering_two

# %%
df = feature_engineering_two( years = range(2016, 2022))

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'game_id', 'season', 'game_time', 'period', 'period_time',
#        'event_type', 'team_id', 'team_name', 'coordinates_x', 'coordinates_y',
#        'shooter', 'goalie', 'shot_type', 'empty_net', 'strength',
#        'situation_code', 'previous_event_name', 'previous_event_x',
#        'previous_event_y', 'previous_event_timeperiod', 'isHomeTeam',
#        'friendly_skaters', 'opponent_skaters', 'current_event_timeseconds',
#        'previous_event_timeseconds', 'time_since_last_event', 'rebound',
#        'distance_from_last_event', 'angle_shot_prev', 'angle_shot', 'speed',
#        'angle_change'],
#       dtype='object')

# %%
filtered = df[[  'distance_shot', 'game_id', 'period', 'previous_event_name','previous_event_x', 'previous_event_y',  'event_type', 'coordinates_x', 'coordinates_y','shot_type', 'empty_net',  'rebound',  'speed','angle_change', 'distance_from_last_event', 'strength', 'friendly_skaters', 'opponent_skaters']]

# %%
filtered[filtered['rebound'] == True]
# Out:
#            game_id  period previous_event_name  previous_event_x  \
# 2       2016020001       1         missed-shot             -72.0
# 3       2016020001       1         missed-shot              77.0
# 6       2016020001       1         missed-shot             -85.0
# 10      2016020001       1        shot-on-goal              34.0
# 11      2016020001       1        shot-on-goal              34.0
# ...            ...     ...                 ...               ...
# 474646  2021030416       2         missed-shot             -74.0
# 474649  2021030416       3         missed-shot              69.0
# 474650  2021030416       3        shot-on-goal             -43.0
# 474651  2021030416       3         missed-shot             -65.0
# 474657  2021030416       3        shot-on-goal             -61.0
#
#         previous_event_y    event_type  coordinates_x  coordinates_y  \
# 2                    0.0  shot-on-goal           23.0          -38.0
# 3                   -2.0  shot-on-goal           33.0          -15.0
# 6                   -8.0          goal          -70.0            1.0
# 10                  20.0  shot-on-goal           34.0          -25.0
# 11                 -25.0          goal           82.0            3.0
# ...                  ...           ...            ...            ...
# 474646              18.0  shot-on-goal          -60.0           -4.0
# 474649              -1.0  shot-on-goal          -43.0           -3.0
# 474650              -3.0  shot-on-goal          -62.0           11.0
# 474651              -4.0  shot-on-goal          -81.0            0.0
# 474657             -29.0  shot-on-goal          -79.0           -1.0
#
#        shot_type  empty_net  rebound      speed  angle_change  \
# 2          wrist      False     True   5.684341     29.931512
# 3           slap      False     True   2.414752      5.532757
# 6          wrist      False     True   5.830952      2.992781
# 10          slap      False     True   5.000000     44.427061
# 11      backhand      False     True  55.569776     47.642545
# ...          ...        ...      ...        ...           ...
# 474646     wrist      False     True  13.038405      7.839381
# 474649     wrist      False     True  11.201786      1.560453
# 474650     wrist      False     True   3.371550      5.468458
# 474651    tip-in      False     True   0.785353      1.487868
# 474657  backhand      False     True  11.095545     10.601143
#
#         distance_from_last_event       strength  friendly_skaters  \
# 2                     102.318131  Even Strength                 5
# 3                      45.880279  Even Strength                 5
# 6                      17.492856  Even Strength                 5
# 10                     45.000000  Even Strength                 5
# 11                     55.569776  Even Strength                 5
# ...                          ...            ...               ...
# 474646                 26.076810  Even Strength                 5
# 474649                112.017856  Even Strength                 5
# 474650                 23.600847  Even Strength                 5
# 474651                 16.492423  Even Strength                 5
# 474657                 33.286634  Even Strength                 5
#
#         opponent_skaters
# 2                      5
# 3                      5
# 6                      5
# 10                     5
# 11                     5
# ...                  ...
# 474646                 5
# 474649                 5
# 474650                 5
# 474651                 5
# 474657                 5
#
# [133687 rows x 17 columns]

# %%
filtered[filtered['strength'] != "Even Strength"]
# Out:
#            game_id  period previous_event_name  previous_event_x  \
# 16      2016020001       1             faceoff             -69.0
# 17      2016020001       1        blocked-shot              59.0
# 19      2016020001       1             faceoff              69.0
# 20      2016020001       1             faceoff              20.0
# 21      2016020001       1        blocked-shot              55.0
# ...            ...     ...                 ...               ...
# 474605  2021030415       3             faceoff              69.0
# 474606  2021030415       3         missed-shot              34.0
# 474643  2021030416       2            takeaway              46.0
# 474644  2021030416       2             faceoff              69.0
# 474645  2021030416       2             faceoff              69.0
#
#         previous_event_y    event_type  coordinates_x  coordinates_y  \
# 16                  22.0  shot-on-goal          -60.0           34.0
# 17                   1.0  shot-on-goal          -79.0          -13.0
# 19                  21.0  shot-on-goal           71.0          -21.0
# 20                  22.0  shot-on-goal           35.0           22.0
# 21                 -13.0  shot-on-goal           85.0          -14.0
# ...                  ...           ...            ...            ...
# 474605              22.0  shot-on-goal           60.0           31.0
# 474606               1.0  shot-on-goal           84.0          -10.0
# 474643              39.0  shot-on-goal          -70.0           25.0
# 474644             -22.0  shot-on-goal           65.0           23.0
# 474645              22.0  shot-on-goal           68.0          -14.0
#
#        shot_type  empty_net  rebound      speed  angle_change  \
# 16         wrist      False    False   0.652174      0.000000
# 17         wrist      False    False   4.474462      0.000000
# 19          snap      False    False   4.671955      0.000000
# 20          slap      False    False   0.535714      0.000000
# 21         wrist      False    False  15.008331      0.000000
# ...          ...        ...      ...        ...           ...
# 474605      slap      False    False   0.979071      0.000000
# 474606     wrist      False     True  25.597851     64.476575
# 474643     wrist      False    False  16.691682      0.000000
# 474644     wrist      False    False   1.737593      0.000000
# 474645     wrist      False    False   6.002314      0.000000
#
#         distance_from_last_event      strength  friendly_skaters  \
# 16                     15.000000    Power Play                 5
# 17                    138.708327    Power Play                 5
# 19                     42.047592    Power Play                 5
# 20                     15.000000    Power Play                 5
# 21                     30.016662    Power Play                 5
# ...                          ...           ...               ...
# 474605                 12.727922    Power Play                 5
# 474606                 51.195703    Power Play                 5
# 474643                116.841773  Short-Handed                 4
# 474644                 45.177428    Power Play                 5
# 474645                 36.013886    Power Play                 5
#
#         opponent_skaters
# 16                     4
# 17                     4
# 19                     4
# 20                     4
# 21                     4
# ...                  ...
# 474605                 4
# 474606                 4
# 474643                 5
# 474644                 4
# 474645                 4
#
# [80564 rows x 17 columns]
