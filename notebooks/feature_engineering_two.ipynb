# %%
import sys, os 
sys.path.append(os.path.abspath('..'))
import numpy as np
import os
import pandas as pd
from ift6758.data.feature_enginerring_pt2 import feature_engineering_two

# %%
df = feature_engineering_two( years = range(2016, 2022))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df = feature_engineering_two()
#
# TypeError: feature_engineering_two() missing 1 required positional argument: 'years'

# %%
df.columns
# Out:
# Index(['game_id', 'season', 'game_time', 'period', 'period_time', 'event_type',
#        'team_id', 'team_name', 'coordinates_x', 'coordinates_y', 'shooter',
#        'goalie', 'shot_type', 'empty_net', 'strength', 'situation_code',
#        'previous_event_name', 'previous_event_x', 'previous_event_y',
#        'previous_event_timeperiod', 'isHomeTeam', 'friendly_skaters',
#        'opponent_skaters', 'current_event_timeseconds',
#        'previous_event_timeseconds', 'time_since_last_event', 'rebound',
#        'distance_from_last_event', 'angle_shot_prev', 'angle_shot', 'speed',
#        'angle_change'],
#       dtype='object')

# %%
filtered = df[[  'game_id', 'period', 'previous_event_name','previous_event_x', 'previous_event_y',  'event_type', 'coordinates_x', 'coordinates_y','shot_type', 'empty_net',  'rebound',  'speed','angle_change', 'distance_from_last_event', 'strength', 'friendly_skaters', 'opponent_skaters']]

# %%
filtered[filtered['rebound'] == True]
# Out:
#           game_id  period previous_event_name  previous_event_x  \
# 0      2016020001       1        blocked-shot             -61.0
# 2      2016020001       1         missed-shot             -72.0
# 3      2016020001       1         missed-shot              77.0
# 6      2016020001       1         missed-shot             -85.0
# 10     2016020001       1        shot-on-goal              34.0
# ...           ...     ...                 ...               ...
# 80383  2016030416       2         missed-shot              75.0
# 80385  2016030416       3         missed-shot              43.0
# 80386  2016030416       3        blocked-shot              41.0
# 80388  2016030416       3        shot-on-goal              84.0
# 80393  2016030416       3        shot-on-goal              71.0
#
#        previous_event_y    event_type  coordinates_x  coordinates_y shot_type  \
# 0                  11.0  shot-on-goal          -77.0            5.0     wrist
# ...
